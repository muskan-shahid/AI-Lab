# %%
# !pip install -U google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.13/dist-packages (2.22.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.57.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)

# %%
from google import genai
client = genai.Client(api_key="")

# %%
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents="Hello"
)

print(response.text)
# Out:
# Hello! How can I help you today?

# %%
while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye 👋")
        break

    print("Sending to Gemini...")

    response = client.models.generate_content(
        model="gemini-3.6-flash",
        contents=user_input
    )

    print("Chatbot:", response.text)
# Out:
# You: hello
# Sending to Gemini...
# Chatbot: Hello! How can I help you today?
# You: tell me about Ai
# Sending to Gemini...
# Chatbot: **Artificial Intelligence (AI)** is the branch of computer science dedicated to creating systems capable of performing tasks that traditionally require human intelligence. These tasks include learning, reasoning, problem-solving, understanding natural language, recognizing patterns, and making decisions.
#
# Here is a breakdown of how AI works, its different types, how it impacts our lives, and the big questions surrounding its future.
#
# ---
#
# ### 1. How Does AI Work?
# At its core, modern AI relies on **data** and **algorithms** (rules for solving problems). Instead of a human writing code for every possible scenario, AI systems learn from vast amounts of data.
#
# * **Machine Learning (ML):** A subset of AI where computers learn from data to improve their performance on a task without being explicitly programmed. For example, show a machine 100,000 photos of cats and dogs, and it will learn to tell them apart.
# * **Deep Learning & Neural Networks:** A more advanced form of ML inspired by the structure of the human brain. It uses layers of interconnected "nodes" to process complex data like speech, images, and natural language.
# * **Large Language Models (LLMs):** The tech behind tools like ChatGPT. They analyze massive amounts of text to predict the most likely next word in a sentence, allowing them to converse, write code, and answer questions.
#
# ---
#
# ### 2. The Main Types of AI
#
# AI is generally categorized into three levels based on capability:
#
# 1. **Narrow AI (Weak AI):**
#    * **What it is:** AI designed to perform a specific task exceptionally well.
#    * **Current Status:** **This is all the AI we have today.**
#    * **Examples:** Facial recognition, Google Search, Siri, self-driving cars, and ChatGPT. Even though ChatGPT seems smart, it only processes and generates text based on patterns—it doesn't "think" or have feelings.
#
# 2. **Artificial General Intelligence (AGI / Strong AI):**
#    * **What it is:** Hypothetical AI that possesses human-level intelligence across *any* intellectual domain. An AGI could learn to play chess, write a novel, diagnose a disease, and build a house just as a human could.
#    * **Current Status:** Does not exist yet. Scientists debate whether it is decades away or impossible.
#
# 3. **Artificial Superintelligence (ASI):**
#    * **What it is:** A theoretical future where AI far surpasses human intelligence in every field, from scientific creativity to social skills.
#
# ---
#
# ### 3. Everyday Examples of AI
# You likely use AI dozens of times a day without realizing it:
#
# * **Entertainment:** Recommendation algorithms on Netflix, Spotify, and TikTok.
# * **Finance:** Fraud detection systems that flag suspicious credit card charges instantly.
# * **Healthcare:** AI analyzing medical scans (X-rays, MRIs) to spot tumors faster than human doctors.
# * **Navigation:** Google Maps predicting traffic and finding the fastest route.
# * **Smartphones:** Autocorrect, predictive text, and photo enhancement tools.
#
# ---
#
# ### 4. The Recent Boom: Generative AI
# Over the past few years, AI shifted from **analyzing** data to **creating** content. This is called **Generative AI**.
# * **Text:** ChatGPT, Claude, Gemini (writing essays, coding, translating).
# * **Images:** Midjourney, DALL-E, Stable Diffusion (generating art and photo-realistic images from text prompts).
# * **Audio & Video:** Tools that can generate realistic voice clones or create video from scratch (like OpenAI's Sora).
#
# ---
#
# ### 5. Benefits and Opportunities
# * **Increased Productivity:** Automating repetitive, tedious tasks (data entry, scheduling, basic customer service).
# * **Scientific Breakthroughs:** AI accelerates drug discovery, models climate change, and solves complex mathematical problems (e.g., DeepMind’s AlphaFold predicting protein structures).
# * **Personalized Learning & Medicine:** Custom tutoring for students and tailored treatments for patients.
#
# ---
#
# ### 6. Risks, Challenges, and Ethical Concerns
# As AI rapidly advances, society faces several critical challenges:
#
# * **Job Displacement:** Automation may eliminate millions of jobs in entry-level coding, customer support, writing, and administrative roles, forcing a shift in the labor market.
# * **Bias and Discrimination:** AI systems learn from human data, which contains human biases. An AI used for hiring might inadvertently discriminate against certain demographics if trained on biased historical data.
# * **Misinformation & Deepfakes:** Generative AI makes it easy to create convincing fake images, audio, and videos, threatening political stability and trust in media.
# * **Intellectual Property:** AI models are trained on billions of copyrighted books, articles, and artworks without compensating the original creators.
# * **"Hallucinations":** LLMs sometimes state incorrect facts with total confidence.
#
# ---
#
# ### Summary
# Artificial Intelligence is not magic, nor is it a sci-fi robot trying to take over the world (yet). It is a powerful tool—a modern "electricity"—that amplifies human capability. Whether its impact is net-positive or net-negative will depend on how governments, tech companies, and society choose to regulate and use it.
